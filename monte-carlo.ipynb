# %% [markdown]
# # High-Level Overview of Monte Carlo Simulation of Portfolio Returns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Download data
aapl = pd.read_csv('data/AAPL_CLOSE.txt',index_col='Date',parse_dates=True)
cisco = pd.read_csv('data/CISCO_CLOSE.txt',index_col='Date',parse_dates=True)
ibm = pd.read_csv('data/IBM_CLOSE.txt',index_col='Date',parse_dates=True)
amzn = pd.read_csv('data/AMZN_CLOSE.txt',index_col='Date',parse_dates=True)

stocks = pd.concat([aapl, cisco, ibm, amzn], axis=1)
stocks.columns = ['aapl', 'cisco', 'ibm', 'amzn']

# %%
stocks.head()
# Out:
#                  aapl      cisco         ibm    amzn
# Date
# 2012-01-03  52.848787  15.617341  157.578371  179.03
# 2012-01-04  53.132802  15.919125  156.935540  177.51
# 2012-01-05  53.722681  15.860445  156.191208  177.61
# 2012-01-06  54.284287  15.801764  154.398046  182.61
# 2012-01-09  54.198183  15.902359  153.594506  178.56

# %%
mean_daily_ret = stocks.pct_change(1).mean()
stocks.pct_change(1).corr()
# Out:
#            aapl     cisco       ibm      amzn
# aapl   1.000000  0.301990  0.297498  0.235487
# cisco  0.301990  1.000000  0.424672  0.284470
# ibm    0.297498  0.424672  1.000000  0.258492
# amzn   0.235487  0.284470  0.258492  1.000000

# %% [markdown]
# ## We can simulate through thousands of possible allocations

# %%
stocks.head()
# Out:
#                  aapl      cisco         ibm    amzn
# Date
# 2012-01-03  52.848787  15.617341  157.578371  179.03
# 2012-01-04  53.132802  15.919125  156.935540  177.51
# 2012-01-05  53.722681  15.860445  156.191208  177.61
# 2012-01-06  54.284287  15.801764  154.398046  182.61
# 2012-01-09  54.198183  15.902359  153.594506  178.56

# %%
stock_normed = stocks/stocks.iloc[0]
stock_normed.plot()
# Out:
# <Axes: xlabel='Date'>
